# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/home/r3l1chunt3r/Documents/property data.csv', delimiter= ';')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data
# Out:
#   PID,ST_NUM,ST_NAME,OWN_OCCUPIED,NUM_BEDROOMS,NUM_BATH,SQ_FT
# 0                    100001000,104,PUTNAM,Y,3,1,1000
# 1                 100002000,197,LEXINGTON,N,3,1.5,--
# 2                   100003000,,LEXINGTON,N,n/a,1,850
# 3                100004000,201,BERKELEY,12,1,NaN,700
# 4                           ,203,BERKELEY,Y,3,2,1600
# 5                  100006000,207,BERKELEY,Y,NA,1,800
# 6              100007000,NA,WASHINGTON,,2,HURLEY,950
# 7                       100008000,213,TREMONT,Y,1,1,
# 8                  100009000,215,TREMONT,Y,na,2,1800

# %%
data.head()
# Out:
#   PID,ST_NUM,ST_NAME,OWN_OCCUPIED,NUM_BEDROOMS,NUM_BATH,SQ_FT
# 0                    100001000,104,PUTNAM,Y,3,1,1000
# 1                 100002000,197,LEXINGTON,N,3,1.5,--
# 2                   100003000,,LEXINGTON,N,n/a,1,850
# 3                100004000,201,BERKELEY,12,1,NaN,700
# 4                           ,203,BERKELEY,Y,3,2,1600

# %%
data.tail()
# Out:
#   PID,ST_NUM,ST_NAME,OWN_OCCUPIED,NUM_BEDROOMS,NUM_BATH,SQ_FT
# 4                           ,203,BERKELEY,Y,3,2,1600
# 5                  100006000,207,BERKELEY,Y,NA,1,800
# 6              100007000,NA,WASHINGTON,,2,HURLEY,950
# 7                       100008000,213,TREMONT,Y,1,1,
# 8                  100009000,215,TREMONT,Y,na,2,1800

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 1 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   PID,ST_NUM,ST_NAME,OWN_OCCUPIED,NUM_BEDROOMS,NUM_BATH,SQ_FT  9 non-null      object
# dtypes: object(1)
# memory usage: 200.0+ bytes

# %%
data.describe(include = 'all')
# Out:
#        PID,ST_NUM,ST_NAME,OWN_OCCUPIED,NUM_BEDROOMS,NUM_BATH,SQ_FT
# count                                                   9
# unique                                                  9
# top                      100003000,,LEXINGTON,N,n/a,1,850
# freq                                                    1

# %%
import pandas as pd
import numpy as np

# %%
Mobile_Banking = pd.read_excel('/home/r3l1chunt3r/Documents/Mobile_Banking .xlsx')

# %%
Mobile_Banking
# Out:
#     Number  Gender Age Range Have Bak Account Bank account connected to MB  \
# 0        1    Male     21-30              Yes              Current Account
# 1        2  Female     21-30              Yes              Current Account
# 2        3  Female     21-30              Yes              Current Account
# 3        4  Female     21-30              Yes              Current Account
# 4        5  Female     21-30              Yes              Current Account
# 5        6  Female     31-40              Yes              Savings Account
# 6        7    Male     21-30              Yes              Current Account
# 7        8    Male     21-30              Yes              Current Account
# 8        9    Male     21-30              Yes              Current Account
# 9       10  Female     21-30              Yes              Current Account
# 10      11  Female     21-30              Yes              Savings Account
# ...

# %%
Mobile_Banking.head()
# Out:
#    Number  Gender Age Range Have Bak Account Bank account connected to MB  \
# 0       1    Male     21-30              Yes              Current Account
# 1       2  Female     21-30              Yes              Current Account
# 2       3  Female     21-30              Yes              Current Account
# 3       4  Female     21-30              Yes              Current Account
# 4       5  Female     21-30              Yes              Current Account
#
#                 use Importance      Benefit     Bank Visit  MbSafety  \
# 0  Airtime Purchase       Very  CostCharges  FewTimesAyear  Somewhat
# 1    Money Transfer       Very  GoodService  FewTimesAyear  Somewhat
# 2   Making Payments       Very  CostCharges  FewTimesAyear      Very
# 3  Airtime Purchase        NaN  GoodService  FewTimesAyear  Somewhat
# 4   Making Payments       Very  CostCharges  FewTimesAyear      Very
#
#     Influence        Satisfaction
# 0  TimeSaving  HighlySatisfactory
# 1  TimeSaving  HighlySatisfactory
# ...

# %%
Mobile_Banking.tail()
# Out:
#     Number  Gender Age Range Have Bak Account Bank account connected to MB  \
# 38      40    Male     21-30              Yes              Current Account
# 39      43  Female     21-30              Yes              Savings Account
# 40      45    Male     21-30              Yes                         None
# 41      46  Female     31-40              Yes              Current Account
# 42      47    Male     21-30              Yes              Current Account
#
#                 use Importance      Benefit     Bank Visit  MbSafety  \
# 38    Cash Withdraw   Somewhat  GoodService  FewTimesAyear      Very
# 39   Money Transfer       Very  GoodService      OnceMonth      Very
# 40   Money Transfer       Very  GoodService  FewTimesAyear  Somewhat
# 41  Making Payments       Very  CostCharges  FewTimesAyear      Very
# 42    Cash Withdraw       Very  GoodService  FewTimesAyear  Somewhat
#
#      Influence        Satisfaction
# 38  TimeSaving        Satisfactory
# ...

# %%
Mobile_Banking["total"] = Mobile_Banking["Jan"] + Mobile_Banking["Feb"] + Mobile_Banking["Mar"]

# %%
Mobile_Banking.describe(include = 'all')
# Out:
#            Number Gender Age Range Have Bak Account  \
# count   43.000000     43        43               43
# unique        NaN      2         3                1
# top           NaN   Male     21-30              Yes
# freq          NaN     23        36               43
# mean    22.674419    NaN       NaN              NaN
# std     13.412363    NaN       NaN              NaN
# min      1.000000    NaN       NaN              NaN
# 25%     11.500000    NaN       NaN              NaN
# 50%     22.000000    NaN       NaN              NaN
# 75%     33.500000    NaN       NaN              NaN
# max     47.000000    NaN       NaN              NaN
#
#        Bank account connected to MB              use Importance      Benefit  \
# count                            43               43         42           43
# unique                            4                4          2            2
# top                 Current Account  Making Payments       Very  CostCharges
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
Mobile_Banking = pd.read_excel('/home/r3l1chunt3r/Documents/Mobile_Banking .xlsx')

# %%
Mobile_Banking.plot()

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1, 2, 3, 4, 5])
plt.ylabel('some numbers')
# Out:
# Text(0, 0.5, 'some numbers')

# %%
plt.show()
